# %%
# Title: Cellpose Image Processing Pipeline for Cytoplasm Mask Generation

# Description:
# This Python script processes cytoplasm images using a custom-trained Cellpose model to generate cell masks. 
# It allows the user to specify various parameters such as input/output directories, cell diameter, flow threshold, 
# cell probability threshold, and output format. The script leverages a custom model path and processes all single-channel 
# AF488 cytoplasm images (`*_c1_AF488.tif`) from the specified input directory. The generated masks are saved in the 
# chosen format (`png` or `tiff`) in the output directory.

# Model Training Workflow:
# - The Cellpose model was first trained on the base model `cyto2_cp3` (or Cyto 2).
# - Sample images were organized into a folder named `CellPose Training` for training purposes.
# - Three representative images (tiles) were selected to ensure good representation of cytoplasmic features.
# - These sample images were used to generate initial masks. The labels were manually corrected to improve accuracy.
# - After correcting the labels, the `Train new model with image + masks in folder` option was used in the Cellpose GUI.
# - This process generated the custom-trained model, which is now utilized in this pipeline.

# Key Features:
# - **Custom Model Loading**: Uses the custom-trained Cellpose model for cytoplasm mask generation.
# - **Parameter Flexibility**: Allows enforcement of fixed cell diameters, adjusting thresholds, and selecting output formats.
# - **Batch Processing**: Processes all matching images in the input directory with real-time progress updates using `tqdm`.
# - **Output Customization**: Masks are saved as 16-bit images to accommodate labels beyond 255.

# %%
from tqdm import tqdm
import time
import os
import glob
from skimage.io import imread, imsave
from cellpose import models
import numpy as np

def process_images(
    input_dir,
    output_dir,
    custom_model_path,
    channels=[0, 0],
    diameter=200,     #Def target diameter
    enforce_diameter=True,
    flow_threshold=0.4,
    cellprob_threshold=0.0,
    output_format="png"
):
    """
    Process images in input_dir using a custom Cellpose model, saving the masks
    into output_dir, optionally enforcing a fixed diameter and choosing output format.
    
    Parameters
    ----------
    input_dir : str
        Folder containing input images (e.g., `*_c1_AF488.tif`).
    output_dir : str
        Folder where masks will be saved.
    custom_model_path : str
        Path to your custom-trained Cellpose model (a .pth file).
    channels : list of int
        Channel specification for Cellpose; for single-channel use [0,0].
    diameter : float
        Desired cell diameter in pixels. Used only if enforce_diameter=True.
    enforce_diameter : bool
        If True, will use the provided 'diameter' value rather than letting Cellpose guess.
    flow_threshold : float
        Flow threshold passed to Cellpose `eval()`.
    cellprob_threshold : float
        Cell probability threshold passed to Cellpose `eval()`.
    output_format : str
        File format for output masks. Either 'png' or 'tiff'.
    """

    # Validate output format
    if output_format.lower() not in ["png", "tiff", "tif"]:
        raise ValueError(f"output_format must be 'png' or 'tiff', got {output_format}")

    # Create output directory
    os.makedirs(output_dir, exist_ok=True)

    # Load the custom model directly as CellposeModel (bypassing _size.npy check)
    model = models.CellposeModel(
        gpu=True, 
        pretrained_model=custom_model_path
    )

    # Decide on diameter
    if enforce_diameter:
        # Always use this diameter
        final_diameter = diameter
    else:
        # Let the model pick the diameter if diameter=0
        if diameter == 0:
            final_diameter = model.diam_labels
        else:
            final_diameter = diameter

    # Gather input files
    image_files = glob.glob(os.path.join(input_dir, "*_c1_AF488.tif"))
    print(f"Found {len(image_files)} files to process.")

    # Start a timer for overall processing
    start_time = time.time()

    #for img_path in image_files:
    for img_path in tqdm(image_files, desc="Processing images", unit="image"):
        # Read image
        img = imread(img_path)

        # Run Cellpose
        masks, flows, styles = model.eval(
            img,
            diameter=final_diameter,
            channels=channels,
            flow_threshold=flow_threshold,
            cellprob_threshold=cellprob_threshold
        )

        # Prepare output filename
        base_name = os.path.splitext(os.path.basename(img_path))[0]
        new_base_name = base_name.replace("Phenotype_Tile-", "Phenotype_CellMask_Tile-")
        
        if output_format.lower() in ["tiff", "tif"]:
            save_path = os.path.join(output_dir, new_base_name + ".tiff")
        else:
            save_path = os.path.join(output_dir, new_base_name + ".png")
        
        # Save mask (16-bit to be safe if labels go above 255)
        imsave(save_path, masks.astype(np.uint16))

        #print(f"Saved mask to: {save_path}")
    # End timer
    end_time = time.time()
    total_time = end_time - start_time
    print(f"\nProcessing completed in {total_time:.2f} seconds.")

if __name__ == "__main__":
    # --------------------------
    # USER-SPECIFIC SETTINGS
    # --------------------------
    input_dir = r"D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells"
    output_dir = r"D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2"
    custom_model_path = r"S:/CellPose Training Images/CellPoseTraining2/TIFF/gamma_adjusted_images/Cytoplasm/models/CP_20250107_123623"
    os.makedirs(output_dir, exist_ok=True)
    
    # Choose your desired parameters:
    channels = [0, 0]               # Single-channel cytoplasm images
    diameter = 200                  # enforce 200 px diameter
    enforce_diameter = True         # True => override model's guess
    flow_threshold = 0.6
    cellprob_threshold = 0.0
    output_format = "png"          # Options: 'png' or 'tiff'

    # Run the pipeline
    process_images(
        input_dir=input_dir,
        output_dir=output_dir,
        custom_model_path=custom_model_path,
        channels=channels,
        diameter=diameter,
        enforce_diameter=enforce_diameter,
        flow_threshold=flow_threshold,
        cellprob_threshold=cellprob_threshold,
        output_format=output_format
    )
# Out:
# Found 360 files to process.
# Processing images:   0%|          | 0/360 [00:00<?, ?image/s]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-023_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   0%|          | 1/360 [00:23<2:22:44, 23.86s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-024_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   1%|          | 2/360 [01:05<3:24:34, 34.29s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-025_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   1%|          | 3/360 [01:53<4:00:52, 40.48s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-026_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   1%|          | 4/360 [02:43<4:22:01, 44.16s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-027_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   1%|▏         | 5/360 [13:07<24:59:57, 253.52s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-028_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   2%|▏         | 6/360 [13:55<18:03:48, 183.70s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-029_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   2%|▏         | 7/360 [14:40<13:32:29, 138.10s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-030_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   2%|▏         | 8/360 [27:05<32:23:24, 331.26s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-031_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   2%|▎         | 9/360 [38:53<43:47:22, 449.12s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-032_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   3%|▎         | 10/360 [49:10<48:42:19, 500.97s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-033_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   3%|▎         | 11/360 [59:53<52:46:17, 544.35s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-034_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   3%|▎         | 12/360 [1:00:38<37:56:16, 392.46s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-035_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   4%|▎         | 13/360 [1:11:45<45:52:00, 475.85s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-036_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   4%|▍         | 14/360 [1:22:01<49:48:13, 518.19s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-037_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   4%|▍         | 15/360 [1:22:49<36:03:55, 376.33s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-038_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   4%|▍         | 16/360 [1:23:37<26:31:04, 277.51s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-039_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   5%|▍         | 17/360 [1:24:22<19:47:14, 207.68s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-040_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   5%|▌         | 18/360 [1:37:31<36:19:36, 382.39s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-041_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   5%|▌         | 19/360 [1:38:15<26:34:37, 280.58s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-042_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   6%|▌         | 20/360 [1:38:41<19:17:04, 204.19s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-045_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   6%|▌         | 21/360 [1:39:26<14:43:46, 156.42s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-046_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   6%|▌         | 22/360 [1:51:28<30:37:10, 326.13s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-047_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:   6%|▋         | 23/360 [1:52:17<22:44:49, 243.00s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-048_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:
/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-376_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  89%|████████▉ | 322/360 [12:54:45<1:35:49, 151.29s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-377_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  90%|████████▉ | 323/360 [13:06:19<3:13:36, 313.95s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-378_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  90%|█████████ | 324/360 [13:17:01<4:07:29, 412.50s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-379_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  90%|█████████ | 325/360 [13:26:56<4:32:29, 467.13s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-380_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  91%|█████████ | 326/360 [13:27:49<3:14:19, 342.91s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-381_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  91%|█████████ | 327/360 [13:39:30<4:07:44, 450.44s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-382_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  91%|█████████ | 328/360 [13:40:27<2:57:19, 332.47s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-383_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  91%|█████████▏| 329/360 [13:41:32<2:10:13, 252.03s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-384_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  92%|█████████▏| 330/360 [13:42:32<1:37:16, 194.56s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-385_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  92%|█████████▏| 331/360 [13:43:20<1:12:49, 150.66s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-386_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  92%|█████████▏| 332/360 [13:44:11<56:18, 120.66s/image]  C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-387_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  92%|█████████▎| 333/360 [13:45:07<45:34, 101.29s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-388_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  93%|█████████▎| 334/360 [13:45:55<36:58, 85.32s/image] C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-389_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  93%|█████████▎| 335/360 [13:56:37<1:45:02, 252.10s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-390_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  93%|█████████▎| 336/360 [14:09:10<2:41:02, 402.60s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-391_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  94%|█████████▎| 337/360 [14:09:57<1:53:25, 295.89s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-392_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  94%|█████████▍| 338/360 [14:10:35<1:20:07, 218.53s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-393_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  94%|█████████▍| 339/360 [14:11:13<57:29, 164.26s/image]  C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-394_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  94%|█████████▍| 340/360 [14:11:58<42:51, 128.56s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-397_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  95%|█████████▍| 341/360 [14:12:17<30:14, 95.51s/image] C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-398_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  95%|█████████▌| 342/360 [14:12:48<22:51, 76.19s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-399_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  95%|█████████▌| 343/360 [14:13:21<17:55, 63.24s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-400_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  96%|█████████▌| 344/360 [14:14:06<15:27, 57.95s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-401_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  96%|█████████▌| 345/360 [14:14:52<13:34, 54.33s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-402_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  96%|█████████▌| 346/360 [14:15:43<12:27, 53.37s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-403_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  96%|█████████▋| 347/360 [14:16:30<11:07, 51.33s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-404_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  97%|█████████▋| 348/360 [14:17:14<09:51, 49.31s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-405_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  97%|█████████▋| 349/360 [14:17:57<08:38, 47.16s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-406_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  97%|█████████▋| 350/360 [14:18:42<07:44, 46.49s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-407_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  98%|█████████▊| 351/360 [14:19:21<06:38, 44.29s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-408_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  98%|█████████▊| 352/360 [14:20:00<05:42, 42.83s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-409_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  98%|█████████▊| 353/360 [14:20:45<05:05, 43.59s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-410_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  98%|█████████▊| 354/360 [14:21:29<04:22, 43.71s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-411_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  99%|█████████▊| 355/360 [14:22:11<03:35, 43.20s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-412_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  99%|█████████▉| 356/360 [14:22:55<02:52, 43.24s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-413_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  99%|█████████▉| 357/360 [14:23:35<02:07, 42.45s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-414_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images:  99%|█████████▉| 358/360 [14:24:21<01:26, 43.43s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-415_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images: 100%|█████████▉| 359/360 [14:25:04<00:43, 43.27s/image]C:\Users\syede\AppData\Local\Temp\ipykernel_10756\229957258.py:96: UserWarning: D:/Easin/OPS_Nov_2024/TIFF/gamma_adjusted_images/cells/masks2\Phenotype_CellMask_Tile-416_c1_AF488.png is a low contrast image
#   imsave(save_path, masks.astype(np.uint16))
# Processing images: 100%|██████████| 360/360 [14:25:53<00:00, 144.32s/image]
# Processing completed in 51953.52 seconds.
